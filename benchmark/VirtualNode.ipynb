# %% [markdown]
# ## Virtual Node Example

# %% [markdown]
# ### Define a model

# %%
import sys 
sys.path.append("..")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from dgl.nn import AvgPooling
import dgl.function as fn
from ogb.graphproppred.mol_encoder import AtomEncoder, BondEncoder

from gtrick import VirtualNode

# %%
class EGINConv(nn.Module):
    def __init__(self, emb_dim):
        '''
            emb_dim (int): node embedding dimensionality
        '''

        super(EGINConv, self).__init__()

        self.mlp = nn.Sequential(nn.Linear(emb_dim, emb_dim),
                                 nn.BatchNorm1d(emb_dim),
                                 nn.ReLU(),
                                 nn.Linear(emb_dim, emb_dim))
        self.eps = nn.Parameter(torch.Tensor([0]))

    def reset_parameters(self):
        for c in self.mlp.children():
            if hasattr(c, 'reset_parameters'):
                c.reset_parameters()
        nn.init.constant_(self.eps.data, 0)

    def forward(self, g, x, edge_embedding):
        with g.local_scope():
            g.ndata['x'] = x
            g.apply_edges(fn.copy_u('x', 'm'))
            g.edata['m'] = F.relu(g.edata['m'] + edge_embedding)
            g.update_all(fn.copy_e('m', 'm'), fn.sum('m', 'new_x'))
            out = self.mlp((1 + self.eps) * x + g.ndata['new_x'])

            return out

# %%
class EGIN(nn.Module):

    def __init__(self, hidden_channels, out_channels, num_layers,
                 dropout, task_type):

        super(EGIN, self).__init__()

        self.node_encoder = AtomEncoder(hidden_channels)
        self.edge_encoder = BondEncoder(hidden_channels)

        self.convs = nn.ModuleList()

        for _ in range(num_layers-1):
            self.convs.append(
                VirtualNode(
                    EGINConv(hidden_channels),
                    hidden_channels,
                    hidden_channels,
                    dropout
                )
            )
        
        self.convs.append(
            EGINConv(hidden_channels)
        )

        self.dropout = dropout

        self.task_type = task_type

        self.pool = AvgPooling()

        self.out = nn.Linear(hidden_channels, out_channels)

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()

        self.out.reset_parameters()

    def forward(self, g, x, ex):
        h = self.node_encoder(x)
        eh = self.edge_encoder(ex)

        for i, conv in enumerate(self.convs[:-1]):
            if i == 0:
                h, vh = conv(g, h, eh)
            else:
                h, vh = conv(g, h, eh, vh)
            
        h = self.convs[-1](g, h, eh)

        h = self.pool(g, h)
        h = self.out(h)

        return h

# %% [markdown]
# ### Graph Property Prediction

# %%
import argparse
from ogb.graphproppred import DglGraphPropPredDataset
from graph_pred import run_graph_pred

# %%
# !nvidia-smi
# Out:
# Wed Apr 20 03:29:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.142.00   Driver Version: 450.142.00   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            On   | 00000000:00:1B.0 Off |                    0 |
# | N/A   42C    P8    15W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla T4            On   | 00000000:00:1C.0 Off |                    0 |
# | N/A   41C    P8    15W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla T4            On   | 00000000:00:1D.0 Off |                    0 |
# | N/A   43C    P8    16W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla T4            On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   41C    P8    15W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
parser = argparse.ArgumentParser(
    description='train graph property prediction')
parser.add_argument("--dataset", type=str, default="ogbg-molhiv",
                    choices=["ogbg-molhiv"])
parser.add_argument("--dataset_path", type=str, default="/home/ubuntu/.dgl_dataset",
                    help="path to dataset")
parser.add_argument('--device', type=int, default=0)
parser.add_argument('--log_steps', type=int, default=1)
parser.add_argument('--num_layers', type=int, default=5)
parser.add_argument('--hidden_channels', type=int, default=256)
parser.add_argument('--dropout', type=float, default=0.5)
parser.add_argument('--lr', type=float, default=0.001)
parser.add_argument("--batch_size", type=int, default=128,
                    help="batch size")
parser.add_argument('--num_workers', type=int, default=0,
                    help='number of workers (default: 0)')
parser.add_argument('--epochs', type=int, default=500)
parser.add_argument('--runs', type=int, default=5)
parser.add_argument('--patience', type=int, default=30)
args = parser.parse_args(args=[])
print(args)
# Out:
# Namespace(batch_size=128, dataset='ogbg-molhiv', dataset_path='/home/ubuntu/.dgl_dataset', device=0, dropout=0.5, epochs=500, hidden_channels=256, log_steps=1, lr=0.001, num_layers=5, num_workers=0, patience=30, runs=5)

# %%
dataset = DglGraphPropPredDataset(
    name=args.dataset, root=args.dataset_path)

model = EGIN(args.hidden_channels,
                dataset.num_tasks, args.num_layers,
                args.dropout, dataset.task_type)

# %%
run_graph_pred(args, model, dataset)
# Out:
# Run: 01, Epoch: 01, Loss: 0.0420, Train: 0.6862, Valid: 0.7034 Test: 0.6634
# Run: 01, Epoch: 02, Loss: 0.0357, Train: 0.7200, Valid: 0.7163 Test: 0.6742
# Run: 01, Epoch: 03, Loss: 0.0348, Train: 0.7432, Valid: 0.7408 Test: 0.7326
# Run: 01, Epoch: 04, Loss: 0.0336, Train: 0.7460, Valid: 0.6760 Test: 0.6520
# EarlyStopping counter: 1 out of 30
#
# Run: 01, Epoch: 05, Loss: 0.0331, Train: 0.7687, Valid: 0.7180 Test: 0.7107
# EarlyStopping counter: 2 out of 30
#
# Run: 01, Epoch: 06, Loss: 0.0327, Train: 0.7622, Valid: 0.7355 Test: 0.6883
# EarlyStopping counter: 3 out of 30
#
# Run: 01, Epoch: 07, Loss: 0.0322, Train: 0.7805, Valid: 0.7394 Test: 0.7261
# EarlyStopping counter: 4 out of 30
#
# Run: 01, Epoch: 08, Loss: 0.0331, Train: 0.7654, Valid: 0.7443 Test: 0.6877
# Run: 01, Epoch: 09, Loss: 0.0323, Train: 0.7457, Valid: 0.7680 Test: 0.7487
# Run: 01, Epoch: 10, Loss: 0.0318, Train: 0.7777, Valid: 0.7974 Test: 0.7359
# Run: 01, Epoch: 11, Loss: 0.0312, Train: 0.7791, Valid: 0.7692 Test: 0.7410
# EarlyStopping counter: 1 out of 30
#
# Run: 01, Epoch: 12, Loss: 0.0308, Train: 0.7766, Valid: 0.7506 Test: 0.7058
# EarlyStopping counter: 2 out of 30
#
# Run: 01, Epoch: 13, Loss: 0.0307, Train: 0.7731, Valid: 0.7929 Test: 0.7276
# EarlyStopping counter: 3 out of 30
#
# Run: 01, Epoch: 14, Loss: 0.0306, Train: 0.7902, Valid: 0.7963 Test: 0.7585
# EarlyStopping counter: 4 out of 30
#
# Run: 01, Epoch: 15, Loss: 0.0301, Train: 0.7783, Valid: 0.7916 Test: 0.7467
# EarlyStopping counter: 5 out of 30
#
# Run: 01, Epoch: 16, Loss: 0.0307, Train: 0.7640, Valid: 0.7661 Test: 0.7456
# EarlyStopping counter: 6 out of 30
#
# Run: 01, Epoch: 17, Loss: 0.0300, Train: 0.7919, Valid: 0.7766 Test: 0.7374
# EarlyStopping counter: 7 out of 30
#
# Run: 01, Epoch: 18, Loss: 0.0302, Train: 0.7895, Valid: 0.8086 Test: 0.7310
# Run: 01, Epoch: 19, Loss: 0.0295, Train: 0.7939, Valid: 0.7860 Test: 0.7050
# EarlyStopping counter: 1 out of 30
#
# Run: 01, Epoch: 20, Loss: 0.0295, Train: 0.7815, Valid: 0.7955 Test: 0.7275
# EarlyStopping counter: 2 out of 30
#
# Run: 01, Epoch: 21, Loss: 0.0287, Train: 0.7966, Valid: 0.8165 Test: 0.7653
# Run: 01, Epoch: 22, Loss: 0.0300, Train: 0.7826, Valid: 0.7927 Test: 0.7493
# EarlyStopping counter: 1 out of 30
#
# Run: 01, Epoch: 23, Loss: 0.0292, Train: 0.8093, Valid: 0.7520 Test: 0.6847
# EarlyStopping counter: 2 out of 30
#
# Run: 01, Epoch: 24, Loss: 0.0283, Train: 0.7993, Valid: 0.7715 Test: 0.7236
# EarlyStopping counter: 3 out of 30
#
# Run: 01, Epoch: 25, Loss: 0.0283, Train: 0.8014, Valid: 0.7577 Test: 0.7531
# EarlyStopping counter: 4 out of 30
#
# Run: 01, Epoch: 26, Loss: 0.0279, Train: 0.8008, Valid: 0.7701 Test: 0.7198
# EarlyStopping counter: 5 out of 30
#
# Run: 01, Epoch: 27, Loss: 0.0282, Train: 0.8043, Valid: 0.7940 Test: 0.7323
# EarlyStopping counter: 6 out of 30
#
# Run: 01, Epoch: 28, Loss: 0.0278, Train: 0.8143, Valid: 0.7942 Test: 0.7459
# EarlyStopping counter: 7 out of 30
#
# Run: 01, Epoch: 29, Loss: 0.0278, Train: 0.7905, Valid: 0.8167 Test: 0.6769
# Run: 01, Epoch: 30, Loss: 0.0272, Train: 0.7993, Valid: 0.8039 Test: 0.7508
# EarlyStopping counter: 1 out of 30
#
# Run: 01, Epoch: 31, Loss: 0.0273, Train: 0.8080, Valid: 0.8346 Test: 0.7488
# Run: 01, Epoch: 32, Loss: 0.0269, Train: 0.8075, Valid: 0.7854 Test: 0.7212
# EarlyStopping counter: 1 out of 30
#
# Run: 01, Epoch: 33, Loss: 0.0274, Train: 0.8011, Valid: 0.7893 Test: 0.7330
# EarlyStopping counter: 2 out of 30
#
# Run: 01, Epoch: 34, Loss: 0.0271, Train: 0.8175, Valid: 0.7836 Test: 0.7204
# EarlyStopping counter: 3 out of 30
#
# Run: 01, Epoch: 35, Loss: 0.0267, Train: 0.8110, Valid: 0.8044 Test: 0.7339
# EarlyStopping counter: 4 out of 30
#
# Run: 01, Epoch: 36, Loss: 0.0266, Train: 0.8195, Valid: 0.8136 Test: 0.7377
# EarlyStopping counter: 5 out of 30
#
# Run: 01, Epoch: 37, Loss: 0.0270, Train: 0.8119, Valid: 0.8091 Test: 0.7489
# EarlyStopping counter: 6 out of 30
#
# Run: 01, Epoch: 38, Loss: 0.0265, Train: 0.8176, Valid: 0.7954 Test: 0.7461
# EarlyStopping counter: 7 out of 30
#
# Run: 01, Epoch: 39, Loss: 0.0269, Train: 0.8148, Valid: 0.7966 Test: 0.7292
# EarlyStopping counter: 8 out of 30
#
# Run: 01, Epoch: 40, Loss: 0.0265, Train: 0.8158, Valid: 0.7849 Test: 0.7022
# EarlyStopping counter: 9 out of 30
#
# Run: 01, Epoch: 41, Loss: 0.0263, Train: 0.8119, Valid: 0.7626 Test: 0.7354
# EarlyStopping counter: 10 out of 30
#
# Run: 01, Epoch: 42, Loss: 0.0263, Train: 0.8061, Valid: 0.8138 Test: 0.7294
# EarlyStopping counter: 11 out of 30
#
# Run: 01, Epoch: 43, Loss: 0.0263, Train: 0.8170, Valid: 0.7224 Test: 0.7122
# EarlyStopping counter: 12 out of 30
#
# Run: 01, Epoch: 44, Loss: 0.0260, Train: 0.8188, Valid: 0.8056 Test: 0.7359
# EarlyStopping counter: 13 out of 30
#
# Run: 01, Epoch: 45, Loss: 0.0262, Train: 0.8079, Valid: 0.8232 Test: 0.7539
# EarlyStopping counter: 14 out of 30
#
# Run: 01, Epoch: 46, Loss: 0.0261, Train: 0.8138, Valid: 0.7192 Test: 0.7369
# EarlyStopping counter: 15 out of 30
#
# Run: 01, Epoch: 47, Loss: 0.0256, Train: 0.8185, Valid: 0.7605 Test: 0.6753
# EarlyStopping counter: 16 out of 30
#
# Run: 01, Epoch: 48, Loss: 0.0255, Train: 0.8177, Valid: 0.7689 Test: 0.7562
# EarlyStopping counter: 17 out of 30
#
# Run: 01, Epoch: 49, Loss: 0.0255, Train: 0.8304, Valid: 0.7984 Test: 0.7534
# EarlyStopping counter: 18 out of 30
#
# Run: 01, Epoch: 50, Loss: 0.0257, Train: 0.8291, Valid: 0.7933 Test: 0.6724
# EarlyStopping counter: 19 out of 30
#
# Run: 01, Epoch: 51, Loss: 0.0253, Train: 0.8232, Valid: 0.8026 Test: 0.7105
# EarlyStopping counter: 20 out of 30
#
# Run: 01, Epoch: 52, Loss: 0.0251, Train: 0.8225, Valid: 0.7985 Test: 0.7499
# EarlyStopping counter: 21 out of 30
#
# Run: 01, Epoch: 53, Loss: 0.0251, Train: 0.8180, Valid: 0.7820 Test: 0.7115
# EarlyStopping counter: 22 out of 30
#
# Run: 01, Epoch: 54, Loss: 0.0245, Train: 0.8222, Valid: 0.7831 Test: 0.6953
# EarlyStopping counter: 23 out of 30
#
# Run: 01, Epoch: 55, Loss: 0.0249, Train: 0.8311, Valid: 0.8019 Test: 0.7443
# EarlyStopping counter: 24 out of 30
#
# Run: 01, Epoch: 56, Loss: 0.0246, Train: 0.8231, Valid: 0.7979 Test: 0.6815
# EarlyStopping counter: 25 out of 30
#
# Run: 01, Epoch: 57, Loss: 0.0250, Train: 0.8288, Valid: 0.7877 Test: 0.7467
# EarlyStopping counter: 26 out of 30
#
# Run: 01, Epoch: 58, Loss: 0.0248, Train: 0.8302, Valid: 0.7943 Test: 0.7317
# EarlyStopping counter: 27 out of 30
#
# Run: 01, Epoch: 59, Loss: 0.0250, Train: 0.8350, Valid: 0.8020 Test: 0.7509
# EarlyStopping counter: 28 out of 30
#
# Run: 01, Epoch: 60, Loss: 0.0246, Train: 0.8353, Valid: 0.7552 Test: 0.7048
# EarlyStopping counter: 29 out of 30
#
# Run: 01, Epoch: 61, Loss: 0.0243, Train: 0.8360, Valid: 0.7635 Test: 0.7259
# EarlyStopping counter: 30 out of 30
#
# Run 01:
# Best Train: 0.8360
# Best Valid: 0.8346
#   Final Train: 0.8080
#   Final Test: 0.7488
# Run: 02, Epoch: 01, Loss: 0.0420, Train: 0.6914, Valid: 0.6492 Test: 0.7085
# Run: 02, Epoch: 02, Loss: 0.0348, Train: 0.7606, Valid: 0.7476 Test: 0.7030
# Run: 02, Epoch: 03, Loss: 0.0333, Train: 0.7685, Valid: 0.7266 Test: 0.7140
# EarlyStopping counter: 1 out of 30
#
# Run: 02, Epoch: 04, Loss: 0.0323, Train: 0.7789, Valid: 0.7338 Test: 0.7303
# EarlyStopping counter: 2 out of 30
#
# Run: 02, Epoch: 05, Loss: 0.0315, Train: 0.7859, Valid: 0.7187 Test: 0.6865
# EarlyStopping counter: 3 out of 30
#
# Run: 02, Epoch: 06, Loss: 0.0310, Train: 0.7699, Valid: 0.7295 Test: 0.7108
# EarlyStopping counter: 4 out of 30
#
# Run: 02, Epoch: 07, Loss: 0.0304, Train: 0.7812, Valid: 0.7568 Test: 0.6736
# Run: 02, Epoch: 08, Loss: 0.0303, Train: 0.7799, Valid: 0.7264 Test: 0.7062
# EarlyStopping counter: 1 out of 30
#
# Run: 02, Epoch: 09, Loss: 0.0298, Train: 0.7420, Valid: 0.5895 Test: 0.6012
# EarlyStopping counter: 2 out of 30
#
# Run: 02, Epoch: 10, Loss: 0.0300, Train: 0.7902, Valid: 0.7620 Test: 0.7362
# Run: 02, Epoch: 11, Loss: 0.0304, Train: 0.7827, Valid: 0.7238 Test: 0.7002
# EarlyStopping counter: 1 out of 30
#
# Run: 02, Epoch: 12, Loss: 0.0293, Train: 0.7944, Valid: 0.7687 Test: 0.7261
# Run: 02, Epoch: 13, Loss: 0.0286, Train: 0.7775, Valid: 0.7498 Test: 0.7200
# EarlyStopping counter: 1 out of 30
#
# Run: 02, Epoch: 14, Loss: 0.0287, Train: 0.7907, Valid: 0.7741 Test: 0.7475
# Run: 02, Epoch: 15, Loss: 0.0284, Train: 0.7970, Valid: 0.6976 Test: 0.7093
# EarlyStopping counter: 1 out of 30
#
# Run: 02, Epoch: 16, Loss: 0.0282, Train: 0.7843, Valid: 0.7311 Test: 0.7235
# EarlyStopping counter: 2 out of 30
#
# Run: 02, Epoch: 17, Loss: 0.0279, Train: 0.8028, Valid: 0.7103 Test: 0.7249
# EarlyStopping counter: 3 out of 30
#
# Run: 02, Epoch: 18, Loss: 0.0277, Train: 0.7962, Valid: 0.7105 Test: 0.6764
# EarlyStopping counter: 4 out of 30
#
# Run: 02, Epoch: 19, Loss: 0.0279, Train: 0.8069, Valid: 0.7285 Test: 0.7328
# EarlyStopping counter: 5 out of 30
#
# Run: 02, Epoch: 20, Loss: 0.0273, Train: 0.8111, Valid: 0.7706 Test: 0.7287
# EarlyStopping counter: 6 out of 30
#
# Run: 02, Epoch: 21, Loss: 0.0277, Train: 0.8053, Valid: 0.7274 Test: 0.7356
# EarlyStopping counter: 7 out of 30
#
# Run: 02, Epoch: 22, Loss: 0.0268, Train: 0.8213, Valid: 0.7916 Test: 0.7484
# Run: 02, Epoch: 23, Loss: 0.0271, Train: 0.8089, Valid: 0.6753 Test: 0.7333
# EarlyStopping counter: 1 out of 30
#
# Run: 02, Epoch: 24, Loss: 0.0269, Train: 0.7998, Valid: 0.6793 Test: 0.7034
# EarlyStopping counter: 2 out of 30
#
# Run: 02, Epoch: 25, Loss: 0.0270, Train: 0.8008, Valid: 0.6857 Test: 0.6872
# EarlyStopping counter: 3 out of 30
#
# Run: 02, Epoch: 26, Loss: 0.0269, Train: 0.8202, Valid: 0.7750 Test: 0.7320
# EarlyStopping counter: 4 out of 30
#
# Run: 02, Epoch: 27, Loss: 0.0279, Train: 0.7978, Valid: 0.6607 Test: 0.7096
# EarlyStopping counter: 5 out of 30
#
# Run: 02, Epoch: 28, Loss: 0.0270, Train: 0.7917, Valid: 0.6879 Test: 0.7183
# EarlyStopping counter: 6 out of 30
#
# Run: 02, Epoch: 29, Loss: 0.0297, Train: 0.7954, Valid: 0.7416 Test: 0.6740
# EarlyStopping counter: 7 out of 30
#
# Run: 02, Epoch: 30, Loss: 0.0272, Train: 0.8104, Valid: 0.7695 Test: 0.7093
# EarlyStopping counter: 8 out of 30
#
# Run: 02, Epoch: 31, Loss: 0.0263, Train: 0.8098, Valid: 0.7907 Test: 0.7595
# EarlyStopping counter: 9 out of 30
#
# Run: 02, Epoch: 32, Loss: 0.0266, Train: 0.8055, Valid: 0.7490 Test: 0.6422
# EarlyStopping counter: 10 out of 30
#
# Run: 02, Epoch: 33, Loss: 0.0263, Train: 0.8190, Valid: 0.7300 Test: 0.7170
# EarlyStopping counter: 11 out of 30
#
# Run: 02, Epoch: 34, Loss: 0.0261, Train: 0.7984, Valid: 0.7205 Test: 0.6975
# EarlyStopping counter: 12 out of 30
#
# Run: 02, Epoch: 35, Loss: 0.0266, Train: 0.8194, Valid: 0.7355 Test: 0.7215
# EarlyStopping counter: 13 out of 30
#
# Run: 02, Epoch: 36, Loss: 0.0259, Train: 0.8039, Valid: 0.7408 Test: 0.7278
# EarlyStopping counter: 14 out of 30
#
# Run: 02, Epoch: 37, Loss: 0.0255, Train: 0.8100, Valid: 0.7185 Test: 0.7188
# EarlyStopping counter: 15 out of 30
#
# Run: 02, Epoch: 38, Loss: 0.0254, Train: 0.8152, Valid: 0.7303 Test: 0.6601
# EarlyStopping counter: 16 out of 30
#
# Run: 02, Epoch: 39, Loss: 0.0249, Train: 0.8149, Valid: 0.7156 Test: 0.7448
# EarlyStopping counter: 17 out of 30
#
# Run: 02, Epoch: 40, Loss: 0.0253, Train: 0.8120, Valid: 0.6262 Test: 0.6775
# EarlyStopping counter: 18 out of 30
#
# Run: 02, Epoch: 41, Loss: 0.0252, Train: 0.8197, Valid: 0.7035 Test: 0.6928
# EarlyStopping counter: 19 out of 30
#
# Run: 02, Epoch: 42, Loss: 0.0249, Train: 0.8124, Valid: 0.7627 Test: 0.7515
# EarlyStopping counter: 20 out of 30
#
# Run: 02, Epoch: 43, Loss: 0.0254, Train: 0.8261, Valid: 0.7690 Test: 0.7366
# EarlyStopping counter: 21 out of 30
#
# Run: 02, Epoch: 44, Loss: 0.0246, Train: 0.8169, Valid: 0.7168 Test: 0.7324
# EarlyStopping counter: 22 out of 30
#
# Run: 02, Epoch: 45, Loss: 0.0247, Train: 0.8205, Valid: 0.6754 Test: 0.7042
# EarlyStopping counter: 23 out of 30
#
# Run: 02, Epoch: 46, Loss: 0.0248, Train: 0.8279, Valid: 0.7123 Test: 0.7086
# EarlyStopping counter: 24 out of 30
#
# Run: 02, Epoch: 47, Loss: 0.0246, Train: 0.8146, Valid: 0.6245 Test: 0.6941
# EarlyStopping counter: 25 out of 30
#
# Run: 02, Epoch: 48, Loss: 0.0247, Train: 0.8215, Valid: 0.7502 Test: 0.7162
# EarlyStopping counter: 26 out of 30
#
# Run: 02, Epoch: 49, Loss: 0.0247, Train: 0.8210, Valid: 0.6857 Test: 0.7412
# EarlyStopping counter: 27 out of 30
#
# Run: 02, Epoch: 50, Loss: 0.0241, Train: 0.8268, Valid: 0.6866 Test: 0.7048
# EarlyStopping counter: 28 out of 30
#
# Run: 02, Epoch: 51, Loss: 0.0251, Train: 0.8205, Valid: 0.6619 Test: 0.7048
# EarlyStopping counter: 29 out of 30
#
# Run: 02, Epoch: 52, Loss: 0.0274, Train: 0.8112, Valid: 0.6106 Test: 0.7231
# EarlyStopping counter: 30 out of 30
#
# Run 02:
# Best Train: 0.8279
# Best Valid: 0.7916
#   Final Train: 0.8213
#   Final Test: 0.7484
# Run: 03, Epoch: 01, Loss: 0.0412, Train: 0.6887, Valid: 0.6591 Test: 0.6852
# Run: 03, Epoch: 02, Loss: 0.0361, Train: 0.7601, Valid: 0.6451 Test: 0.6325
# EarlyStopping counter: 1 out of 30
#
# Run: 03, Epoch: 03, Loss: 0.0371, Train: 0.7484, Valid: 0.7597 Test: 0.7110
# Run: 03, Epoch: 04, Loss: 0.0330, Train: 0.7692, Valid: 0.6958 Test: 0.6953
# EarlyStopping counter: 1 out of 30
#
# Run: 03, Epoch: 05, Loss: 0.0319, Train: 0.7830, Valid: 0.6754 Test: 0.6605
# EarlyStopping counter: 2 out of 30
#
# Run: 03, Epoch: 06, Loss: 0.0310, Train: 0.7930, Valid: 0.7908 Test: 0.7418
# Run: 03, Epoch: 07, Loss: 0.0302, Train: 0.7943, Valid: 0.7801 Test: 0.7114
# EarlyStopping counter: 1 out of 30
#
# Run: 03, Epoch: 08, Loss: 0.0299, Train: 0.7848, Valid: 0.7535 Test: 0.6882
# EarlyStopping counter: 2 out of 30
#
# Run: 03, Epoch: 09, Loss: 0.0293, Train: 0.7996, Valid: 0.7632 Test: 0.7056
# EarlyStopping counter: 3 out of 30
#
# Run: 03, Epoch: 10, Loss: 0.0294, Train: 0.7854, Valid: 0.6793 Test: 0.7107
# EarlyStopping counter: 4 out of 30
#
# Run: 03, Epoch: 11, Loss: 0.0291, Train: 0.8061, Valid: 0.7321 Test: 0.6980
# EarlyStopping counter: 5 out of 30
#
# Run: 03, Epoch: 12, Loss: 0.0290, Train: 0.7926, Valid: 0.7176 Test: 0.7129
# EarlyStopping counter: 6 out of 30
#
# Run: 03, Epoch: 13, Loss: 0.0285, Train: 0.7997, Valid: 0.7914 Test: 0.7206
# Run: 03, Epoch: 14, Loss: 0.0285, Train: 0.8070, Valid: 0.7504 Test: 0.7368
# EarlyStopping counter: 1 out of 30
#
# Run: 03, Epoch: 15, Loss: 0.0274, Train: 0.8009, Valid: 0.7756 Test: 0.7505
# EarlyStopping counter: 2 out of 30
#
# Run: 03, Epoch: 16, Loss: 0.0288, Train: 0.8061, Valid: 0.7665 Test: 0.7156
# EarlyStopping counter: 3 out of 30
#
# Run: 03, Epoch: 17, Loss: 0.0283, Train: 0.8005, Valid: 0.7622 Test: 0.7239
# EarlyStopping counter: 4 out of 30
#
# Run: 03, Epoch: 18, Loss: 0.0277, Train: 0.8074, Valid: 0.7711 Test: 0.7254
# EarlyStopping counter: 5 out of 30
#
# Run: 03, Epoch: 19, Loss: 0.0270, Train: 0.8128, Valid: 0.7660 Test: 0.7249
# EarlyStopping counter: 6 out of 30
#
# Run: 03, Epoch: 20, Loss: 0.0270, Train: 0.8120, Valid: 0.7874 Test: 0.7309
# EarlyStopping counter: 7 out of 30
#
# Run: 03, Epoch: 21, Loss: 0.0269, Train: 0.7963, Valid: 0.7122 Test: 0.6819
# EarlyStopping counter: 8 out of 30
#
# Run: 03, Epoch: 22, Loss: 0.0265, Train: 0.7984, Valid: 0.7629 Test: 0.6794
# EarlyStopping counter: 9 out of 30
#
# Run: 03, Epoch: 23, Loss: 0.0269, Train: 0.8142, Valid: 0.7968 Test: 0.7275
# Run: 03, Epoch: 24, Loss: 0.0264, Train: 0.8101, Valid: 0.7811 Test: 0.7275
# EarlyStopping counter: 1 out of 30
#
# Run: 03, Epoch: 25, Loss: 0.0262, Train: 0.7975, Valid: 0.7171 Test: 0.7233
# EarlyStopping counter: 2 out of 30
#
# Run: 03, Epoch: 26, Loss: 0.0261, Train: 0.8142, Valid: 0.7563 Test: 0.7083
# EarlyStopping counter: 3 out of 30
#
# Run: 03, Epoch: 27, Loss: 0.0259, Train: 0.8120, Valid: 0.7198 Test: 0.7601
# EarlyStopping counter: 4 out of 30
#
# Run: 03, Epoch: 28, Loss: 0.0263, Train: 0.8117, Valid: 0.7913 Test: 0.7226
# EarlyStopping counter: 5 out of 30
#
# Run: 03, Epoch: 29, Loss: 0.0259, Train: 0.8095, Valid: 0.8001 Test: 0.7176
# Run: 03, Epoch: 30, Loss: 0.0256, Train: 0.8188, Valid: 0.7975 Test: 0.7394
# EarlyStopping counter: 1 out of 30
#
# Run: 03, Epoch: 31, Loss: 0.0265, Train: 0.8195, Valid: 0.8002 Test: 0.7395
# Run: 03, Epoch: 32, Loss: 0.0261, Train: 0.8175, Valid: 0.8168 Test: 0.7266
# Run: 03, Epoch: 33, Loss: 0.0254, Train: 0.8226, Valid: 0.7635 Test: 0.7439
# EarlyStopping counter: 1 out of 30
#
# Run: 03, Epoch: 34, Loss: 0.0261, Train: 0.8193, Valid: 0.7488 Test: 0.7158
# EarlyStopping counter: 2 out of 30
#
# Run: 03, Epoch: 35, Loss: 0.0262, Train: 0.8192, Valid: 0.7181 Test: 0.7104
# EarlyStopping counter: 3 out of 30
#
# Run: 03, Epoch: 36, Loss: 0.0249, Train: 0.8159, Valid: 0.7538 Test: 0.7274
# EarlyStopping counter: 4 out of 30
#
# Run: 03, Epoch: 37, Loss: 0.0254, Train: 0.8219, Valid: 0.8069 Test: 0.7074
# EarlyStopping counter: 5 out of 30
#
# Run: 03, Epoch: 38, Loss: 0.0260, Train: 0.8107, Valid: 0.6273 Test: 0.7246
# EarlyStopping counter: 6 out of 30
#
# Run: 03, Epoch: 39, Loss: 0.0252, Train: 0.8117, Valid: 0.7840 Test: 0.7034
# EarlyStopping counter: 7 out of 30
#
# Run: 03, Epoch: 40, Loss: 0.0249, Train: 0.8123, Valid: 0.6978 Test: 0.6925
# EarlyStopping counter: 8 out of 30
#
# Run: 03, Epoch: 41, Loss: 0.0252, Train: 0.8191, Valid: 0.6628 Test: 0.7364
# EarlyStopping counter: 9 out of 30
#
# Run: 03, Epoch: 42, Loss: 0.0249, Train: 0.8119, Valid: 0.6897 Test: 0.7185
# EarlyStopping counter: 10 out of 30
#
# Run: 03, Epoch: 43, Loss: 0.0245, Train: 0.8266, Valid: 0.7437 Test: 0.7373
# EarlyStopping counter: 11 out of 30
#
# Run: 03, Epoch: 44, Loss: 0.0243, Train: 0.8338, Valid: 0.7866 Test: 0.7231
# EarlyStopping counter: 12 out of 30
#
# Run: 03, Epoch: 45, Loss: 0.0252, Train: 0.8243, Valid: 0.7709 Test: 0.7246
# EarlyStopping counter: 13 out of 30
#
# Run: 03, Epoch: 46, Loss: 0.0252, Train: 0.8258, Valid: 0.7854 Test: 0.7411
# EarlyStopping counter: 14 out of 30
#
# Run: 03, Epoch: 47, Loss: 0.0242, Train: 0.8256, Valid: 0.7714 Test: 0.7518
# EarlyStopping counter: 15 out of 30
#
# Run: 03, Epoch: 48, Loss: 0.0244, Train: 0.8209, Valid: 0.7954 Test: 0.7527
# EarlyStopping counter: 16 out of 30
#
# Run: 03, Epoch: 49, Loss: 0.0244, Train: 0.8271, Valid: 0.7686 Test: 0.7537
# EarlyStopping counter: 17 out of 30
#
# Run: 03, Epoch: 50, Loss: 0.0241, Train: 0.8349, Valid: 0.7837 Test: 0.7383
# EarlyStopping counter: 18 out of 30
#
# Run: 03, Epoch: 51, Loss: 0.0244, Train: 0.8364, Valid: 0.7838 Test: 0.7435
# EarlyStopping counter: 19 out of 30
#
# Run: 03, Epoch: 52, Loss: 0.0238, Train: 0.8298, Valid: 0.7756 Test: 0.7239
# EarlyStopping counter: 20 out of 30
#
# Run: 03, Epoch: 53, Loss: 0.0240, Train: 0.8195, Valid: 0.6967 Test: 0.7030
# EarlyStopping counter: 21 out of 30
#
# Run: 03, Epoch: 54, Loss: 0.0243, Train: 0.8195, Valid: 0.6775 Test: 0.6877
# EarlyStopping counter: 22 out of 30
#
# Run: 03, Epoch: 55, Loss: 0.0237, Train: 0.8267, Valid: 0.6950 Test: 0.7109
# EarlyStopping counter: 23 out of 30
#
# Run: 03, Epoch: 56, Loss: 0.0243, Train: 0.8248, Valid: 0.7132 Test: 0.6917
# EarlyStopping counter: 24 out of 30
#
# Run: 03, Epoch: 57, Loss: 0.0242, Train: 0.8269, Valid: 0.8019 Test: 0.7408
# EarlyStopping counter: 25 out of 30
#
# Run: 03, Epoch: 58, Loss: 0.0236, Train: 0.8272, Valid: 0.7193 Test: 0.7427
# EarlyStopping counter: 26 out of 30
#
# Run: 03, Epoch: 59, Loss: 0.0233, Train: 0.8420, Valid: 0.7713 Test: 0.7377
# EarlyStopping counter: 27 out of 30
#
# Run: 03, Epoch: 60, Loss: 0.0233, Train: 0.8291, Valid: 0.6931 Test: 0.7311
# EarlyStopping counter: 28 out of 30
#
# Run: 03, Epoch: 61, Loss: 0.0232, Train: 0.8384, Valid: 0.7882 Test: 0.7243
# EarlyStopping counter: 29 out of 30
#
# Run: 03, Epoch: 62, Loss: 0.0234, Train: 0.8372, Valid: 0.6848 Test: 0.6878
# EarlyStopping counter: 30 out of 30
#
# Run 03:
# Best Train: 0.8420
# Best Valid: 0.8168
#   Final Train: 0.8175
#   Final Test: 0.7266
# Run: 04, Epoch: 01, Loss: 0.0404, Train: 0.7066, Valid: 0.7722 Test: 0.6908
# Run: 04, Epoch: 02, Loss: 0.0349, Train: 0.7695, Valid: 0.6816 Test: 0.7109
# EarlyStopping counter: 1 out of 30
#
# Run: 04, Epoch: 03, Loss: 0.0329, Train: 0.7961, Valid: 0.7579 Test: 0.7048
# EarlyStopping counter: 2 out of 30
#
# Run: 04, Epoch: 04, Loss: 0.0326, Train: 0.7925, Valid: 0.6566 Test: 0.6852
# EarlyStopping counter: 3 out of 30
#
# Run: 04, Epoch: 05, Loss: 0.0313, Train: 0.7805, Valid: 0.7081 Test: 0.6798
# EarlyStopping counter: 4 out of 30
#
# Run: 04, Epoch: 06, Loss: 0.0304, Train: 0.7875, Valid: 0.7291 Test: 0.7266
# EarlyStopping counter: 5 out of 30
#
# Run: 04, Epoch: 07, Loss: 0.0298, Train: 0.7994, Valid: 0.7451 Test: 0.7480
# EarlyStopping counter: 6 out of 30
#
# Run: 04, Epoch: 08, Loss: 0.0294, Train: 0.7947, Valid: 0.7269 Test: 0.7128
# EarlyStopping counter: 7 out of 30
#
# Run: 04, Epoch: 09, Loss: 0.0289, Train: 0.7822, Valid: 0.6855 Test: 0.6728
# EarlyStopping counter: 8 out of 30
#
# Run: 04, Epoch: 10, Loss: 0.0296, Train: 0.8003, Valid: 0.7778 Test: 0.7212
# Run: 04, Epoch: 11, Loss: 0.0288, Train: 0.8098, Valid: 0.7841 Test: 0.7280
# Run: 04, Epoch: 12, Loss: 0.0282, Train: 0.7999, Valid: 0.7915 Test: 0.7214
# Run: 04, Epoch: 13, Loss: 0.0275, Train: 0.8112, Valid: 0.7796 Test: 0.7189
# EarlyStopping counter: 1 out of 30
#
# Run: 04, Epoch: 14, Loss: 0.0283, Train: 0.8141, Valid: 0.7778 Test: 0.7007
# EarlyStopping counter: 2 out of 30
#
# Run: 04, Epoch: 15, Loss: 0.0273, Train: 0.8085, Valid: 0.7757 Test: 0.7407
# EarlyStopping counter: 3 out of 30
#
# Run: 04, Epoch: 16, Loss: 0.0283, Train: 0.8077, Valid: 0.7277 Test: 0.7165
# EarlyStopping counter: 4 out of 30
#
# Run: 04, Epoch: 17, Loss: 0.0276, Train: 0.8135, Valid: 0.7765 Test: 0.7168
# EarlyStopping counter: 5 out of 30
#
# Run: 04, Epoch: 18, Loss: 0.0272, Train: 0.8027, Valid: 0.7732 Test: 0.7166
# EarlyStopping counter: 6 out of 30
#
# Run: 04, Epoch: 19, Loss: 0.0274, Train: 0.8096, Valid: 0.7891 Test: 0.7276
# EarlyStopping counter: 7 out of 30
#
# Run: 04, Epoch: 20, Loss: 0.0265, Train: 0.8077, Valid: 0.7318 Test: 0.7238
# EarlyStopping counter: 8 out of 30
#
# Run: 04, Epoch: 21, Loss: 0.0262, Train: 0.8138, Valid: 0.7759 Test: 0.7111
# EarlyStopping counter: 9 out of 30
#
# Run: 04, Epoch: 22, Loss: 0.0266, Train: 0.8077, Valid: 0.7067 Test: 0.7100
# EarlyStopping counter: 10 out of 30
#
# Run: 04, Epoch: 23, Loss: 0.0263, Train: 0.8182, Valid: 0.6694 Test: 0.7150
# EarlyStopping counter: 11 out of 30
#
# Run: 04, Epoch: 24, Loss: 0.0258, Train: 0.8106, Valid: 0.7121 Test: 0.6524
# EarlyStopping counter: 12 out of 30
#
# Run: 04, Epoch: 25, Loss: 0.0270, Train: 0.8171, Valid: 0.8036 Test: 0.7238
# Run: 04, Epoch: 26, Loss: 0.0277, Train: 0.8089, Valid: 0.7810 Test: 0.6606
# EarlyStopping counter: 1 out of 30
#
# Run: 04, Epoch: 27, Loss: 0.0259, Train: 0.8101, Valid: 0.6934 Test: 0.7218
# EarlyStopping counter: 2 out of 30
#
# Run: 04, Epoch: 28, Loss: 0.0262, Train: 0.8256, Valid: 0.6923 Test: 0.7312
# EarlyStopping counter: 3 out of 30
#
# Run: 04, Epoch: 29, Loss: 0.0272, Train: 0.8253, Valid: 0.7129 Test: 0.7358
# EarlyStopping counter: 4 out of 30
#
# Run: 04, Epoch: 30, Loss: 0.0257, Train: 0.8256, Valid: 0.7427 Test: 0.7101
# EarlyStopping counter: 5 out of 30
#
# Run: 04, Epoch: 31, Loss: 0.0254, Train: 0.8220, Valid: 0.7157 Test: 0.7167
# EarlyStopping counter: 6 out of 30
#
# Run: 04, Epoch: 32, Loss: 0.0251, Train: 0.8119, Valid: 0.7008 Test: 0.6898
# EarlyStopping counter: 7 out of 30
#
# Run: 04, Epoch: 33, Loss: 0.0250, Train: 0.8298, Valid: 0.7331 Test: 0.7362
# EarlyStopping counter: 8 out of 30
#
# Run: 04, Epoch: 34, Loss: 0.0255, Train: 0.8270, Valid: 0.7293 Test: 0.7118
# EarlyStopping counter: 9 out of 30
#
# Run: 04, Epoch: 35, Loss: 0.0249, Train: 0.8283, Valid: 0.7404 Test: 0.6991
# EarlyStopping counter: 10 out of 30
#
# Run: 04, Epoch: 36, Loss: 0.0247, Train: 0.8319, Valid: 0.6880 Test: 0.7095
# EarlyStopping counter: 11 out of 30
#
# Run: 04, Epoch: 37, Loss: 0.0247, Train: 0.8282, Valid: 0.7469 Test: 0.7447
# EarlyStopping counter: 12 out of 30
#
# Run: 04, Epoch: 38, Loss: 0.0247, Train: 0.8301, Valid: 0.6634 Test: 0.7264
# EarlyStopping counter: 13 out of 30
#
# Run: 04, Epoch: 39, Loss: 0.0243, Train: 0.8320, Valid: 0.7364 Test: 0.7189
# EarlyStopping counter: 14 out of 30
#
# Run: 04, Epoch: 40, Loss: 0.0242, Train: 0.8319, Valid: 0.7684 Test: 0.7357
# EarlyStopping counter: 15 out of 30
#
# Run: 04, Epoch: 41, Loss: 0.0244, Train: 0.8352, Valid: 0.6855 Test: 0.7316
# EarlyStopping counter: 16 out of 30
#
# Run: 04, Epoch: 42, Loss: 0.0241, Train: 0.8381, Valid: 0.7583 Test: 0.6886
# EarlyStopping counter: 17 out of 30
#
# Run: 04, Epoch: 43, Loss: 0.0240, Train: 0.8354, Valid: 0.6819 Test: 0.6501
# EarlyStopping counter: 18 out of 30
#
# Run: 04, Epoch: 44, Loss: 0.0242, Train: 0.8429, Valid: 0.7272 Test: 0.7128
# EarlyStopping counter: 19 out of 30
#
# Run: 04, Epoch: 45, Loss: 0.0240, Train: 0.8370, Valid: 0.7214 Test: 0.7063
# EarlyStopping counter: 20 out of 30
#
# Run: 04, Epoch: 46, Loss: 0.0237, Train: 0.8249, Valid: 0.7116 Test: 0.6854
# EarlyStopping counter: 21 out of 30
#
# Run: 04, Epoch: 47, Loss: 0.0240, Train: 0.8393, Valid: 0.7006 Test: 0.6776
# EarlyStopping counter: 22 out of 30
#
# Run: 04, Epoch: 48, Loss: 0.0233, Train: 0.8377, Valid: 0.6861 Test: 0.6810
# EarlyStopping counter: 23 out of 30
#
# Run: 04, Epoch: 49, Loss: 0.0237, Train: 0.8470, Valid: 0.7202 Test: 0.7008
# EarlyStopping counter: 24 out of 30
#
# Run: 04, Epoch: 50, Loss: 0.0234, Train: 0.8397, Valid: 0.7773 Test: 0.7411
# EarlyStopping counter: 25 out of 30
#
# Run: 04, Epoch: 51, Loss: 0.0235, Train: 0.8481, Valid: 0.7537 Test: 0.7486
# EarlyStopping counter: 26 out of 30
#
# Run: 04, Epoch: 52, Loss: 0.0233, Train: 0.8496, Valid: 0.7292 Test: 0.7312
# EarlyStopping counter: 27 out of 30
#
# Run: 04, Epoch: 53, Loss: 0.0231, Train: 0.8359, Valid: 0.7074 Test: 0.7023
# EarlyStopping counter: 28 out of 30
#
# Run: 04, Epoch: 54, Loss: 0.0233, Train: 0.8462, Valid: 0.7850 Test: 0.6995
# EarlyStopping counter: 29 out of 30
#
# Run: 04, Epoch: 55, Loss: 0.0232, Train: 0.8318, Valid: 0.6762 Test: 0.6872
# EarlyStopping counter: 30 out of 30
#
# Run 04:
# Best Train: 0.8496
# Best Valid: 0.8036
#   Final Train: 0.8171
#   Final Test: 0.7238
# Run: 05, Epoch: 01, Loss: 0.0399, Train: 0.7213, Valid: 0.6686 Test: 0.6463
# Run: 05, Epoch: 02, Loss: 0.0344, Train: 0.7323, Valid: 0.7804 Test: 0.7251
# Run: 05, Epoch: 03, Loss: 0.0334, Train: 0.7734, Valid: 0.7479 Test: 0.6769
# EarlyStopping counter: 1 out of 30
#
# Run: 05, Epoch: 04, Loss: 0.0322, Train: 0.7724, Valid: 0.6974 Test: 0.7109
# EarlyStopping counter: 2 out of 30
#
# Run: 05, Epoch: 05, Loss: 0.0324, Train: 0.8026, Valid: 0.7504 Test: 0.7168
# EarlyStopping counter: 3 out of 30
#
# Run: 05, Epoch: 06, Loss: 0.0314, Train: 0.7872, Valid: 0.7183 Test: 0.6660
# EarlyStopping counter: 4 out of 30
#
# Run: 05, Epoch: 07, Loss: 0.0299, Train: 0.7815, Valid: 0.7318 Test: 0.7386
# EarlyStopping counter: 5 out of 30
#
# Run: 05, Epoch: 08, Loss: 0.0294, Train: 0.7956, Valid: 0.7845 Test: 0.7244
# Run: 05, Epoch: 09, Loss: 0.0285, Train: 0.8019, Valid: 0.7913 Test: 0.7326
# Run: 05, Epoch: 10, Loss: 0.0289, Train: 0.7926, Valid: 0.7684 Test: 0.7378
# EarlyStopping counter: 1 out of 30
#
# Run: 05, Epoch: 11, Loss: 0.0281, Train: 0.7874, Valid: 0.7614 Test: 0.7033
# EarlyStopping counter: 2 out of 30
#
# Run: 05, Epoch: 12, Loss: 0.0282, Train: 0.7998, Valid: 0.7546 Test: 0.7138
# EarlyStopping counter: 3 out of 30
#
# Run: 05, Epoch: 13, Loss: 0.0276, Train: 0.8094, Valid: 0.7729 Test: 0.7254
# EarlyStopping counter: 4 out of 30
#
# Run: 05, Epoch: 14, Loss: 0.0274, Train: 0.8072, Valid: 0.7642 Test: 0.7289
# EarlyStopping counter: 5 out of 30
#
# Run: 05, Epoch: 15, Loss: 0.0272, Train: 0.8034, Valid: 0.7598 Test: 0.7217
# EarlyStopping counter: 6 out of 30
#
# Run: 05, Epoch: 16, Loss: 0.0272, Train: 0.8196, Valid: 0.7808 Test: 0.7329
# EarlyStopping counter: 7 out of 30
#
# Run: 05, Epoch: 17, Loss: 0.0274, Train: 0.8063, Valid: 0.7886 Test: 0.7354
# EarlyStopping counter: 8 out of 30
#
# Run: 05, Epoch: 18, Loss: 0.0269, Train: 0.7980, Valid: 0.7029 Test: 0.7122
# EarlyStopping counter: 9 out of 30
#
# Run: 05, Epoch: 19, Loss: 0.0264, Train: 0.8050, Valid: 0.7610 Test: 0.7311
# EarlyStopping counter: 10 out of 30
#
# Run: 05, Epoch: 20, Loss: 0.0266, Train: 0.8161, Valid: 0.7010 Test: 0.7582
# EarlyStopping counter: 11 out of 30
#
# Run: 05, Epoch: 21, Loss: 0.0259, Train: 0.8048, Valid: 0.6928 Test: 0.7355
# EarlyStopping counter: 12 out of 30
#
# Run: 05, Epoch: 22, Loss: 0.0261, Train: 0.8108, Valid: 0.7101 Test: 0.7350
# EarlyStopping counter: 13 out of 30
#
# Run: 05, Epoch: 23, Loss: 0.0266, Train: 0.8076, Valid: 0.7390 Test: 0.7285
# EarlyStopping counter: 14 out of 30
#
# Run: 05, Epoch: 24, Loss: 0.0268, Train: 0.8185, Valid: 0.7905 Test: 0.7163
# EarlyStopping counter: 15 out of 30
#
# Run: 05, Epoch: 25, Loss: 0.0257, Train: 0.8086, Valid: 0.7795 Test: 0.7064
# EarlyStopping counter: 16 out of 30
#
# Run: 05, Epoch: 26, Loss: 0.0263, Train: 0.8138, Valid: 0.7632 Test: 0.7183
# EarlyStopping counter: 17 out of 30
#
# Run: 05, Epoch: 27, Loss: 0.0256, Train: 0.8235, Valid: 0.7639 Test: 0.7252
# EarlyStopping counter: 18 out of 30
#
# Run: 05, Epoch: 28, Loss: 0.0250, Train: 0.7884, Valid: 0.6400 Test: 0.7073
# EarlyStopping counter: 19 out of 30
#
# Run: 05, Epoch: 29, Loss: 0.0255, Train: 0.8185, Valid: 0.7673 Test: 0.7172
# EarlyStopping counter: 20 out of 30
#
# Run: 05, Epoch: 30, Loss: 0.0255, Train: 0.8205, Valid: 0.7572 Test: 0.7173
# EarlyStopping counter: 21 out of 30
#
# Run: 05, Epoch: 31, Loss: 0.0262, Train: 0.8215, Valid: 0.7318 Test: 0.7117
# EarlyStopping counter: 22 out of 30
#
# Run: 05, Epoch: 32, Loss: 0.0282, Train: 0.8018, Valid: 0.7105 Test: 0.7083
# EarlyStopping counter: 23 out of 30
#
# Run: 05, Epoch: 33, Loss: 0.0308, Train: 0.7873, Valid: 0.7945 Test: 0.7509
# Run: 05, Epoch: 34, Loss: 0.0275, Train: 0.7877, Valid: 0.6743 Test: 0.7151
# EarlyStopping counter: 1 out of 30
#
# Run: 05, Epoch: 35, Loss: 0.0265, Train: 0.7906, Valid: 0.6589 Test: 0.7078
# EarlyStopping counter: 2 out of 30
#
# Run: 05, Epoch: 36, Loss: 0.0257, Train: 0.7959, Valid: 0.7697 Test: 0.7387
# EarlyStopping counter: 3 out of 30
#
# Run: 05, Epoch: 37, Loss: 0.0263, Train: 0.7969, Valid: 0.7425 Test: 0.7111
# EarlyStopping counter: 4 out of 30
#
# Run: 05, Epoch: 38, Loss: 0.0251, Train: 0.8044, Valid: 0.6565 Test: 0.7039
# EarlyStopping counter: 5 out of 30
#
# Run: 05, Epoch: 39, Loss: 0.0252, Train: 0.8065, Valid: 0.7200 Test: 0.7198
# EarlyStopping counter: 6 out of 30
#
# Run: 05, Epoch: 40, Loss: 0.0249, Train: 0.8000, Valid: 0.7496 Test: 0.6811
# EarlyStopping counter: 7 out of 30
#
# Run: 05, Epoch: 41, Loss: 0.0247, Train: 0.8153, Valid: 0.7752 Test: 0.7046
# EarlyStopping counter: 8 out of 30
#
# Run: 05, Epoch: 42, Loss: 0.0246, Train: 0.8042, Valid: 0.6909 Test: 0.6872
# EarlyStopping counter: 9 out of 30
#
# Run: 05, Epoch: 43, Loss: 0.0244, Train: 0.8241, Valid: 0.7730 Test: 0.7397
# EarlyStopping counter: 10 out of 30
#
# Run: 05, Epoch: 44, Loss: 0.0245, Train: 0.8229, Valid: 0.7015 Test: 0.7267
# EarlyStopping counter: 11 out of 30
#
# Run: 05, Epoch: 45, Loss: 0.0242, Train: 0.8200, Valid: 0.7150 Test: 0.7159
# EarlyStopping counter: 12 out of 30
#
# Run: 05, Epoch: 46, Loss: 0.0242, Train: 0.8153, Valid: 0.7167 Test: 0.7129
# EarlyStopping counter: 13 out of 30
#
# Run: 05, Epoch: 47, Loss: 0.0255, Train: 0.8250, Valid: 0.7968 Test: 0.7048
# Run: 05, Epoch: 48, Loss: 0.0248, Train: 0.8218, Valid: 0.7107 Test: 0.6971
# EarlyStopping counter: 1 out of 30
#
# Run: 05, Epoch: 49, Loss: 0.0241, Train: 0.8207, Valid: 0.6451 Test: 0.7244
# EarlyStopping counter: 2 out of 30
#
# Run: 05, Epoch: 50, Loss: 0.0244, Train: 0.8241, Valid: 0.7931 Test: 0.6936
# EarlyStopping counter: 3 out of 30
#
# Run: 05, Epoch: 51, Loss: 0.0244, Train: 0.8230, Valid: 0.7432 Test: 0.7018
# EarlyStopping counter: 4 out of 30
#
# Run: 05, Epoch: 52, Loss: 0.0237, Train: 0.8369, Valid: 0.7897 Test: 0.7348
# EarlyStopping counter: 5 out of 30
#
# Run: 05, Epoch: 53, Loss: 0.0236, Train: 0.8206, Valid: 0.6523 Test: 0.6850
# EarlyStopping counter: 6 out of 30
#
# Run: 05, Epoch: 54, Loss: 0.0239, Train: 0.8261, Valid: 0.6320 Test: 0.6862
# EarlyStopping counter: 7 out of 30
#
# Run: 05, Epoch: 55, Loss: 0.0241, Train: 0.8258, Valid: 0.7773 Test: 0.7110
# EarlyStopping counter: 8 out of 30
#
# Run: 05, Epoch: 56, Loss: 0.0232, Train: 0.8351, Valid: 0.7995 Test: 0.7211
# Run: 05, Epoch: 57, Loss: 0.0240, Train: 0.8362, Valid: 0.7787 Test: 0.7154
# EarlyStopping counter: 1 out of 30
#
# Run: 05, Epoch: 58, Loss: 0.0233, Train: 0.8410, Valid: 0.7795 Test: 0.7324
# EarlyStopping counter: 2 out of 30
#
# Run: 05, Epoch: 59, Loss: 0.0233, Train: 0.8417, Valid: 0.7945 Test: 0.6975
# EarlyStopping counter: 3 out of 30
#
# Run: 05, Epoch: 60, Loss: 0.0236, Train: 0.8246, Valid: 0.7603 Test: 0.6943
# EarlyStopping counter: 4 out of 30
#
# Run: 05, Epoch: 61, Loss: 0.0230, Train: 0.8337, Valid: 0.7879 Test: 0.7157
# EarlyStopping counter: 5 out of 30
#
# Run: 05, Epoch: 62, Loss: 0.0242, Train: 0.8321, Valid: 0.7872 Test: 0.7115
# EarlyStopping counter: 6 out of 30
#
# Run: 05, Epoch: 63, Loss: 0.0232, Train: 0.8285, Valid: 0.7543 Test: 0.7388
# EarlyStopping counter: 7 out of 30
#
# Run: 05, Epoch: 64, Loss: 0.0229, Train: 0.8346, Valid: 0.7839 Test: 0.7154
# EarlyStopping counter: 8 out of 30
#
# Run: 05, Epoch: 65, Loss: 0.0229, Train: 0.8427, Valid: 0.7737 Test: 0.7286
# EarlyStopping counter: 9 out of 30
#
# Run: 05, Epoch: 66, Loss: 0.0228, Train: 0.8425, Valid: 0.7571 Test: 0.7257
# EarlyStopping counter: 10 out of 30
#
# Run: 05, Epoch: 67, Loss: 0.0230, Train: 0.8511, Valid: 0.8216 Test: 0.7243
# Run: 05, Epoch: 68, Loss: 0.0230, Train: 0.8385, Valid: 0.7975 Test: 0.7135
# EarlyStopping counter: 1 out of 30
#
# Run: 05, Epoch: 69, Loss: 0.0242, Train: 0.8458, Valid: 0.7859 Test: 0.7327
# EarlyStopping counter: 2 out of 30
#
# Run: 05, Epoch: 70, Loss: 0.0231, Train: 0.8440, Valid: 0.7199 Test: 0.7296
# EarlyStopping counter: 3 out of 30
#
# Run: 05, Epoch: 71, Loss: 0.0223, Train: 0.8519, Valid: 0.8011 Test: 0.7259
# EarlyStopping counter: 4 out of 30
#
# Run: 05, Epoch: 72, Loss: 0.0233, Train: 0.8503, Valid: 0.7899 Test: 0.7064
# EarlyStopping counter: 5 out of 30
#
# Run: 05, Epoch: 73, Loss: 0.0232, Train: 0.8480, Valid: 0.7034 Test: 0.6932
# EarlyStopping counter: 6 out of 30
#
# Run: 05, Epoch: 74, Loss: 0.0226, Train: 0.8574, Valid: 0.7655 Test: 0.7270
# EarlyStopping counter: 7 out of 30
#
# Run: 05, Epoch: 75, Loss: 0.0222, Train: 0.8502, Valid: 0.6929 Test: 0.7069
# EarlyStopping counter: 8 out of 30
#
# Run: 05, Epoch: 76, Loss: 0.0221, Train: 0.8515, Valid: 0.7941 Test: 0.7160
# EarlyStopping counter: 9 out of 30
#
# Run: 05, Epoch: 77, Loss: 0.0230, Train: 0.8544, Valid: 0.7949 Test: 0.7423
# EarlyStopping counter: 10 out of 30
#
# Run: 05, Epoch: 78, Loss: 0.0225, Train: 0.8526, Valid: 0.7869 Test: 0.7519
# EarlyStopping counter: 11 out of 30
#
# Run: 05, Epoch: 79, Loss: 0.0226, Train: 0.8563, Valid: 0.7199 Test: 0.7242
# EarlyStopping counter: 12 out of 30
#
# Run: 05, Epoch: 80, Loss: 0.0223, Train: 0.8603, Valid: 0.7246 Test: 0.7534
# EarlyStopping counter: 13 out of 30
#
# Run: 05, Epoch: 81, Loss: 0.0223, Train: 0.8589, Valid: 0.8166 Test: 0.7727
# EarlyStopping counter: 14 out of 30
#
# Run: 05, Epoch: 82, Loss: 0.0220, Train: 0.8597, Valid: 0.7827 Test: 0.7342
# EarlyStopping counter: 15 out of 30
#
# Run: 05, Epoch: 83, Loss: 0.0222, Train: 0.8583, Valid: 0.7632 Test: 0.7491
# EarlyStopping counter: 16 out of 30
#
# Run: 05, Epoch: 84, Loss: 0.0217, Train: 0.8526, Valid: 0.7024 Test: 0.7447
# EarlyStopping counter: 17 out of 30
#
# Run: 05, Epoch: 85, Loss: 0.0220, Train: 0.8639, Valid: 0.7083 Test: 0.7354
# EarlyStopping counter: 18 out of 30
#
# Run: 05, Epoch: 86, Loss: 0.0223, Train: 0.8600, Valid: 0.7885 Test: 0.7262
# EarlyStopping counter: 19 out of 30
#
# Run: 05, Epoch: 87, Loss: 0.0219, Train: 0.8535, Valid: 0.7947 Test: 0.7263
# EarlyStopping counter: 20 out of 30
#
# Run: 05, Epoch: 88, Loss: 0.0221, Train: 0.8531, Valid: 0.7989 Test: 0.7153
# EarlyStopping counter: 21 out of 30
#
# Run: 05, Epoch: 89, Loss: 0.0220, Train: 0.8566, Valid: 0.8056 Test: 0.7281
# EarlyStopping counter: 22 out of 30
#
# Run: 05, Epoch: 90, Loss: 0.0214, Train: 0.8597, Valid: 0.7884 Test: 0.7287
# EarlyStopping counter: 23 out of 30
#
# Run: 05, Epoch: 91, Loss: 0.0216, Train: 0.8589, Valid: 0.7137 Test: 0.7082
# EarlyStopping counter: 24 out of 30
#
# Run: 05, Epoch: 92, Loss: 0.0224, Train: 0.8678, Valid: 0.7879 Test: 0.7343
# EarlyStopping counter: 25 out of 30
#
# Run: 05, Epoch: 93, Loss: 0.0213, Train: 0.8623, Valid: 0.8002 Test: 0.7365
# EarlyStopping counter: 26 out of 30
#
# Run: 05, Epoch: 94, Loss: 0.0216, Train: 0.8545, Valid: 0.7700 Test: 0.7247
# EarlyStopping counter: 27 out of 30
#
# Run: 05, Epoch: 95, Loss: 0.0214, Train: 0.8698, Valid: 0.7945 Test: 0.7089
# EarlyStopping counter: 28 out of 30
#
# Run: 05, Epoch: 96, Loss: 0.0213, Train: 0.8652, Valid: 0.7881 Test: 0.7196
# EarlyStopping counter: 29 out of 30
#
# Run: 05, Epoch: 97, Loss: 0.0212, Train: 0.8732, Valid: 0.7378 Test: 0.7262
# EarlyStopping counter: 30 out of 30
#
# Run 05:
# Best Train: 0.8732
# Best Valid: 0.8216
#   Final Train: 0.8511
#   Final Test: 0.7243
# All runs:
# Best Train: 0.8457 ± 0.0173
# Best Valid: 0.8136 ± 0.0166
#   Final Train: 0.8230 ± 0.0164
#   Final Test: 0.7344 ± 0.0130
